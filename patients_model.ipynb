# %% [markdown]
# <a href="https://colab.research.google.com/github/Nxpze/essencial-project1/blob/model-patients/patients_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ผู้ป่วย**

# %%
# สร้างชื่อ - นามสกุลของผู้ป่วยเอาไปสุ่ม
first_names = [
    "สมชัย", "สมหญิง", "สมศักดิ์", "สมศรี", "สมฤดี",
    "สมหมาย", "สมบัตร", "สมปอง", "สมใจ", "สมนึก",
    "สมสวย", "สมหวัง", "สมภพ", "สมหทัย", "สมควร"
]

last_names = [
    "ประสม", "ประเสริฐ", "ประเสริฐศรี", "ประสงค์", "ประทาน",
    "ประชาชื่น", "ประเสริฐฐาน", "ประจักร", "ประสิทธิ์", "ประสาน",
    "ประชาโชค", "ประมาณตน", "ประดิษฐ์", "ประพันธ์" "ประทีป"
]

# %%
# ประวัติแพ้ยา
allergies_list = [
    "ไม่มี", "ไม่มี", "ไม่มี", "ไม่มี", "ไม่มี", "ไม่มี",  "ไม่มี", "ไม่มี",  "ไม่มี",
    "พาราเซตามอล", "เพนิซิลลิน", "แอสไพริน", "ซัลฟา" , "อัลโลพูรินอล", "เฟนิโทอิน", "ไดโคลฟีแนก"
]

# โรคประจำตัว
diseases_list = [
    "ไม่มี", "ไม่มี", "ไม่มี", "ไม่มี","ไม่มี", "ไม่มี","ไม่มี", "ไม่มี","ไม่มี", "ไม่มี",
    "เบาหวาน", "ความดันโลหิตสูง", "หอบหืด", "ไขมันในเลือดสูง", "โรคหัวใจ", "หลอดเลือดหัวใจตีบ", "HIV"
]

# %%
# อาการตามสี
symptoms_pool = {
    "แดง": [
        "หมดสติ แน่นหน้าอก",
        "หายใจลำบากขั้นรุนแรง",
        "ช็อกจากเสียเลือด",
        "อุบัติเหตุร้ายแรง",
        "ชักเกร็งไม่รู้สึกตัว"
    ],
    "เหลือง": [
        "ปวดท้องเกร็ง ไข้สูง",
        "ปวดศีรษะเฉียบพลัน",
        "แผลฉีกขาดเลือดไหลไม่หยุด",
        "อาเจียนต่อเนื่อง",
        "กระดูกแขนผื่นผิดรูป"
    ],
    "เขียว": [
        "ไอ มีน้ำมูก",
        "ปวดศีรษะเล็กน้อย",
        "ปวดกล้ามเนื้อ",
        "ผื่นคันตามตัว",
        "เจ็บคอ ถ่ายเหลว"
    ],
    "ขาว": [
        "ขอใบรับรองแพทย์",
        "มาตามนัดฟังผลตรวจ",
        "ปรึกษาเรื่องสุขภาพทั่วไป",
        "ขอรับยาเดิม",
        "ฉีดวัคซีนตามนัด"
    ]
}

# %%
import random
import pandas as pd
from datetime import datetime, timedelta
from google.colab import files

# %%
patient_data = []
visit_dt = datetime.now()
today = datetime.now()

# %%
# สุ่มทุกอย่าง ชื่อ วันเกิด เบอร์ อาการ ยา โรคประจำตัว
for i in range(1, 301):
    # รหัส
    patient_id = f"P{i:03d}"
    # ชื่อ
    fullname = f"{random.choice(first_names)} {random.choice(last_names)}"
    # วันเกิด
    dob_dt = today - timedelta(days=random.randint(5 * 365, 90 * 365))
    dob = dob_dt.strftime("%Y-%m-%d")
    # อายุ
    age = today.year - dob_dt.year - ((today.month, today.day) < (dob_dt.month, dob_dt.day))
    # เบอร์โทร
    phone_number = f"08{random.randint(10000000, 99999999)}"
    # แพ้ยา
    allergies = random.choice(allergies_list)
    # โรคประจำตัว
    diseases = random.choice(diseases_list)
    # สี
    urgency_level = random.choice(list(symptoms_pool.keys()))
    # อาการ
    symptom_detail = random.choice(symptoms_pool[urgency_level])

    patient_data.append({
        "รหัสผู้ป่วย": patient_id,
        "ชื่อ - นามสกุล": fullname,
        "วันเกิด": dob,
        "อายุ": age,
        "เบอร์โทรศัพท์": phone_number,
        "ประวัติแพ้ยา": allergies,
        "โรคประจำตัว": diseases,
        "ระดับอาการ": urgency_level,
        "อาการ": symptom_detail,
})

# %%
df_patients = pd.DataFrame(patient_data)
df_patients.to_csv("patients_300.csv", index=False, encoding="utf-8-sig")

print("สร้างข้อมูลผู้ป่วยครบ 300 คนเรียบร้อยแล้ว!")
files.download("patients_300.csv")
# Out:
# สร้างข้อมูลผู้ป่วยครบ 300 คนเรียบร้อยแล้ว!

# %%
# แสดงผล 5 รายการแรกออกมาดู
df_patients.head(20)
# Out:
#    รหัสผู้ป่วย    ชื่อ - นามสกุล     วันเกิด  อายุ เบอร์โทรศัพท์  \
# 0         P001    สมสวย ประดิษฐ์  1991-12-15    34    0865899681
# 1         P002   สมหวัง ประดิษฐ์  1948-07-31    78    0816324339
# 2         P003    สมชัย ประชาโชค  1985-01-29    41    0866324078
# 3         P004     สมหมาย ประทาน  2005-04-12    21    0840497077
# 4         P005    สมหญิง ประสงค์  1998-01-17    28    0830602461
# 5         P006       สมภพ ประทาน  1964-01-15    62    0859620703
# 6         P007   สมหวัง ประดิษฐ์  1936-10-11    89    0884149633
# 7         P008   สมหญิง ประดิษฐ์  2012-12-11    13    0864404527
# 8         P009   สมนึก ประสิทธิ์  2019-02-14     7    0841175260
# 9         P010  สมหมาย ประสิทธิ์  2005-05-16    21    0871494619
# 10        P011    สมชัย ประดิษฐ์  1959-02-17    67    0842994214
# 11        P012   สมหทัย ประชาโชค  2011-12-06    14    0854467865
# 12        P013       สมภพ ประทาน  1968-06-06    58    0856953072
# 13        P014    สมฤดี ประมาณตน  1992-10-19    33    0811056087
# 14        P015   สมปอง ประสิทธิ์  1985-05-29    41    0886553313
# 15        P016     สมใจ ประชาโชค  1952-07-28    74    0874409255
# 16        P017  สมบัตร ประชาชื่น  1946-06-09    80    0854714310
# 17        P018       สมชัย ประสม  2018-12-13     7    0857925320
# 18        P019       สมภพ ประทาน  1997-04-24    29    0896522375
# 19        P020    สมบัตร ประสงค์  1938-11-27    87    0818029771
#
#     ประวัติแพ้ยา      โรคประจำตัว ระดับอาการ                     อาการ
# 0      เฟนิโทอิน            ไม่มี        แดง         หมดสติ แน่นหน้าอก
# 1    พาราเซตามอล           หอบหืด        ขาว           ฉีดวัคซีนตามนัด
# 2          ไม่มี            ไม่มี      เขียว               ไอ มีน้ำมูก
# 3          ไม่มี            ไม่มี      เขียว               ไอ มีน้ำมูก
# 4          ไม่มี           หอบหืด        แดง         อุบัติเหตุร้ายแรง
# 5          ไม่มี              HIV        ขาว               ขอรับยาเดิม
# 6       แอสไพริน            ไม่มี      เขียว             ปวดกล้ามเนื้อ
# 7    พาราเซตามอล            ไม่มี        แดง          ช็อกจากเสียเลือด
# 8          ไม่มี            ไม่มี        ขาว               ขอรับยาเดิม
# 9       แอสไพริน            ไม่มี     เหลือง          อาเจียนต่อเนื่อง
# 10         ไม่มี            ไม่มี      เขียว             ผื่นคันตามตัว
# 11         ไม่มี              HIV     เหลือง          อาเจียนต่อเนื่อง
# 12         ไม่มี            ไม่มี     เหลือง       ปวดท้องเกร็ง ไข้สูง
# 13     เฟนิโทอิน  ความดันโลหิตสูง        ขาว               ขอรับยาเดิม
# 14         ไม่มี            ไม่มี        ขาว  ปรึกษาเรื่องสุขภาพทั่วไป
# 15         ไม่มี         โรคหัวใจ        แดง      ชักเกร็งไม่รู้สึกตัว
# 16         ไม่มี           หอบหืด        แดง          ช็อกจากเสียเลือด
# 17         ไม่มี            ไม่มี     เหลือง       กระดูกแขนผื่นผิดรูป
# 18     เฟนิโทอิน           หอบหืด     เหลือง       กระดูกแขนผื่นผิดรูป
# 19  อัลโลพูรินอล         โรคหัวใจ        ขาว  ปรึกษาเรื่องสุขภาพทั่วไป

# %% [markdown]
# **ผลการรักษา**

# %%
doctors_data = [
    {"D_id": "D001", "doctor_name": "นพ. สมชาย ใจดี", "specialty": "อายุรกรรม", "phone": "081-111-2222"},
    {"D_id": "D002", "doctor_name": "พญ. วิภาดา รักษาดี", "specialty": "กุมารเวชศาสตร์ (หมอเด็ก)", "phone": "081-222-3333"},
    {"D_id": "D003", "doctor_name": "นพ. ธนกฤต เก่งกาจ", "specialty": "ศัลยกรรมกระดูกและข้อ", "phone": "081-333-4444"},
]

# %%
df_doctors = pd.DataFrame(doctors_data)
df_doctors.head(20)
# Out:
#    D_id         doctor_name                 specialty         phone
# 0  D001      นพ. สมชาย ใจดี                 อายุรกรรม  081-111-2222
# 1  D002  พญ. วิภาดา รักษาดี  กุมารเวชศาสตร์ (หมอเด็ก)  081-222-3333
# 2  D003   นพ. ธนกฤต เก่งกาจ      ศัลยกรรมกระดูกและข้อ  081-333-4444

# %%
# เซ็ตอาการ ยา สถานะที่จะเป็นได้
medical_recordsl_rules = {
    # --- Red (แดง - วิกฤต / ฉุกเฉินมาก) ---
    "หมดสติ แน่นหน้าอก": {
        "color": "แดง",
        "diagnosis": "ภาวะกล้ามเนื้อหัวใจขาดเลือดเฉียบพลัน",
        "meds_list": ["Aspirin 300mg, Oxygen Therapy", "Aspirin 300mg, Nitroglycerin SL, O2"],
        "status_list": ["ส่งตัวรักษาต่อโรงพยาบาล (ออกใบรีเฟอร์)"]
    },
    "หายใจลำบากขั้นรุนแรง": {
        "color": "แดง",
        "diagnosis": "ภาวะหายใจล้มเหลว / หอบหืดขั้นรุนแรง",
        "meds_list": ["พ่นยา Ventolin, Oxygen Therapy", "Nebulized Salbutamol, Dexamethasone IV"],
        "status_list": ["ส่งตัวรักษาต่อโรงพยาบาล (ออกใบรีเฟอร์)"]
    },
    "ช็อกจากเสียเลือด": {
        "color": "แดง",
        "diagnosis": "ภาวะช็อกจากการเสียเลือดรุนแรง (Hypovolemic Shock)",
        "meds_list": ["ให้สารน้ำทางหลอดเลือดดำ (NSS/Ringer) เบื้องต้น", "IV Fluid Loading, Stop Bleeding"],
        "status_list": ["ส่งตัวรักษาต่อโรงพยาบาล (ออกใบรีเฟอร์)"]
    },
    "อุบัติเหตุร้ายแรง": {
        "color": "แดง",
        "diagnosis": "การบาดเจ็บรุนแรงจากอุบัติเหตุ (Major Trauma)",
        "meds_list": ["ปฐมพยาบาลเบื้องต้น ห้ามเลือด ดามคอ", "C-spine Immobilization, Morphine IV, NSS"],
        "status_list": ["ส่งตัวรักษาต่อโรงพยาบาล (ออกใบรีเฟอร์)"]
    },
    "ชักเกร็งไม่รู้สึกตัว": {
        "color": "แดง",
        "diagnosis": "ภาวะชักเกร็งต่อเนื่อง (Status Epilepticus)",
        "meds_list": ["Diazepam IV (เบื้องต้น), Open Airway", "Midazolam IM, Oxygen Therapy"],
        "status_list": ["ส่งตัวรักษาต่อโรงพยาบาล (ออกใบรีเฟอร์)"]
    },

    # --- Yellow (เหลือง - ด่วน / ปานกลาง) ---
    "ปวดท้องเกร็ง ไข้สูง": {
        "color": "เหลือง",
        "diagnosis": "ติดเชื้อในระบบทางเดินอาหาร / ไส้ติ่งอักเสบระยะแรก",
        "meds_list": ["Hyoscine 10mg, Buscopan, Paracetamol", "Hyoscine 10mg, Norfloxacin 400mg"],
        "status_list": ["นัดติดตามอาการ / ออกใบนัด", "ติดตามอาการ"]
    },
    "ปวดศีรษะเฉียบพลัน": {
        "color": "เหลือง",
        "diagnosis": "ปวดศีรษะไมเกรนรุนแรง / ความดันโลหิตสูงเฉียบพลัน",
        "meds_list": ["Triptan, Ibuprofen 400mg", "Ergotamine, Paracetamol 500mg"],
        "status_list": ["นัดติดตามอาการ / ออกใบนัด", "อาการดีขึ้น"]
    },
    "แผลฉีกขาดเลือดไหลไม่หยุด": {
        "color": "เหลือง",
        "diagnosis": "แผลฉีกขาด (Laceration Wound)",
        "meds_list": ["ทำแผล เย็บแผล, Tetanus Vaccine, Amoxicillin", "ทำแผล เย็บแผล, Ibuprofen 400mg"],
        "status_list": ["นัดติดตามอาการ / ออกใบนัด (ทำแผล/ตัดไหม)", "อาการดีขึ้น"]
    },
    "อาเจียนต่อเนื่อง": {
        "color": "เหลือง",
        "diagnosis": "กระเพาะอาหารและลำไส้อักเสบ (Gastroenteritis)",
        "meds_list": ["Domperidone 10mg, ORS, Paracetamol", "Ondansetron 4mg, ORS, Plasil"],
        "status_list": ["นัดติดตามอาการ / ออกใบนัด", "อาการดีขึ้น"]
    },
    "กระดูกแขนผื่นผิดรูป": {
        "color": "เหลือง",
        "diagnosis": "สงสัยกระดูกแขนหัก / ข้อต่อหลุด (Fracture/Dislocation)",
        "meds_list": ["ดามแขนชั่วคราว, Paracetamol 500mg", "Splinting, Tramadol, Paracetamol"],
        "status_list": ["นัดติดตามอาการ / ออกใบนัด", "ส่งตัวรักษาต่อโรงพยาบาล (ออกใบรีเฟอร์)"]
    },

    # --- Green (เขียว - ทั่วไป / ไม่ด่วน) ---
    "ไอ มีน้ำมูก": {
        "color": "เขียว",
        "diagnosis": "ติดเชื้อทางเดินหายใจส่วนบน (Common Cold)",
        "meds_list": ["Paracetamol 500mg, CPM", "Antihistamine, Cough Syrup"],
        "status_list": ["หายขาด", "อาการดีขึ้น"]
    },
    "ปวดศีรษะเล็กน้อย": {
        "color": "เขียว",
        "diagnosis": "ปวดศีรษะจากความเครียด (Tension Headache)",
        "meds_list": ["Paracetamol 500mg", "Paracetamol 500mg, พักผ่อน"],
        "status_list": ["หายขาด", "อาการดีขึ้น"]
    },
    "ปวดกล้ามเนื้อ": {
        "color": "เขียว",
        "diagnosis": "กล้ามเนื้ออักเสบ (Myalgia / Office Syndrome)",
        "meds_list": ["Ibuprofen 400mg, Muscle Relaxant", "Analgesic Cream, Paracetamol 500mg"],
        "status_list": ["หายขาด", "อาการดีขึ้น"]
    },
    "ผื่นคันตามตัว": {
        "color": "เขียว",
        "diagnosis": "ผื่นผิวหนังอักเสบ / ลมพิษ (Dermatitis/Urticaria)",
        "meds_list": ["Cetirizine 10mg, Calamine Lotion", "Loratadine 10mg, TA Cream"],
        "status_list": ["หายขาด", "อาการดีขึ้น"]
    },
    "เจ็บคอ ถ่ายเหลว": {
        "color": "เขียว",
        "diagnosis": "คออักเสบร่วมกับลำไส้อักเสบเบื้องต้น",
        "meds_list": ["Amoxicillin 500mg, ORS, Paracetamol", "ORS, Electrolyte, Paracetamol"],
        "status_list": ["หายขาด", "อาการดีขึ้น"]
    },

    # --- White (ขาว - บริการทั่วไป / รับยา / ใบรับรอง) ---
    "ขอใบรับรองแพทย์": {
        "color": "ขาว",
        "diagnosis": "ตรวจรับรองสุขภาพทั่วไป",
        "meds_list": ["ไม่มีการจ่ายยา"],
        "status_list": ["หายขาด"]
    },
    "มาตามนัดฟังผลตรวจ": {
        "color": "ขาว",
        "diagnosis": "ติดตามผลตรวจทางห้องปฏิบัติการ (Lab Follow-up)",
        "meds_list": ["ยาตามโรคเดิมของผู้ป่วย", "ไม่มีการจ่ายยาเพิ่มเติม"],
        "status_list": ["หายขาด", "อาการดีขึ้น"]
    },
    "ปรึกษาเรื่องสุขภาพทั่วไป": {
        "color": "ขาว",
        "diagnosis": "ตรวจสุขภาพทั่วไปและให้คำแนะนำด้านโภชนาการ/การออกกำลังกาย",
        "meds_list": ["Multivitamin Supplement", "Vitamin C 500mg"],
        "status_list": ["หายขาด", "อาการดีขึ้น"]
    },
    "ขอรับยาเดิม": {
        "color": "ขาว",
        "diagnosis": "ติดตามการรักษาโรคประจำตัวเดิม (Routine Refill)",
        "meds_list": ["Amlodipine 5mg (ยาความดันเดิม)", "Metformin 500mg (ยาเบาหวานเดิม)"],
        "status_list": ["หายขาด", "อาการดีขึ้น"]
    },
    "ฉีดวัคซีนตามนัด": {
        "color": "ขาว",
        "diagnosis": "รับวัคซีนป้องกันโรคตามกำหนด",
        "meds_list": ["Influenza Vaccine, Paracetamol 500mg (สำรองเผื่อไข้)", "Hepatitis B Vaccine"],
        "status_list": ["หายขาด"]
    }
}

# %%
patients_list = df_patients.to_dict('records')
medical_records = []
today_date = datetime.now().date()

# %%
medical_records = []

# สุ่ม
for i in range(1, 1001):
    # สุ่มคนไข้ + หมอ
    patient = random.choice(patients_list)
    doctor = random.choice(doctors_data)

    # ดึงอาการของผู้ป่วยคนนั้นมาเช็ก
    symptom = patient.get("อาการ", patient.get("อาการที่มา", "ไอ มีน้ำมูก"))

    # แมปปิ้งผลวินิจฉัย/ยา/สถานะ/สีคัดกรอง จากอาการจริง
    rules_dict = medical_recordsl_rules
    if symptom in rules_dict:
        rule = rules_dict[symptom]
        meds = random.choice(rule["meds_list"])
        status = random.choice(rule["status_list"])
    else:
        meds = "Paracetamol 500mg"
        status = "หายขาด"

    # The treatment date should be based on 'today's' date, not a random day in the past.
    treatment_date = today
    random_hours = random.randint(8, 16)
    random_minutes = random.randint(0, 59)
    random_seconds = random.randint(0, 59)
    treatment_time = treatment_date.replace(
        hour=random_hours, minute=random_minutes, second=random_seconds
    ).strftime("%Y-%m-%d %H:%M:%S")

    # 4. บันทึกข้อมูลพร้อมคอลัมน์ "เวลารักษา"
    medical_records.append({
        "รหัสรักษา": f"{i:03d}",
        "เวลารักษา": treatment_time,
        "รหัสผู้ป่วย": patient.get("รหัสผู้ป่วย") or patient.get("P_id"),
        "รหัสหมอ": doctor["D_id"],
        "ชื่อหมอ": doctor["doctor_name"],
        "อาการที่มา": symptom,
        "ยาที่จะสั่ง": meds,
        "สถานะรักษา": status
    })

# %%
print(f"จำนวนรายการรักษา: {len(df_medical_records)} แถว")
# Out:
# จำนวนรายการรักษา: 1000 แถว

# %%
df_medical_records = pd.DataFrame(medical_records)
df_medical_records.to_csv("medical_records.csv", index=False, encoding="utf-8-sig")

print("สร้างข้อมูลคนเรียบร้อยแล้ว!")
files.download("medical_records.csv")
# Out:
# สร้างข้อมูลคนเรียบร้อยแล้ว!

# %%
df_medical_records.head(20)
# Out:
#    รหัสรักษา            เวลารักษา รหัสผู้ป่วย รหัสหมอ             ชื่อหมอ  \
# 0        001  2026-08-29 09:05:26        P038    D003   นพ. ธนกฤต เก่งกาจ
# 1        002  2026-08-29 12:14:34        P148    D001      นพ. สมชาย ใจดี
# 2        003  2026-08-29 15:58:23        P051    D002  พญ. วิภาดา รักษาดี
# 3        004  2026-08-29 16:39:41        P253    D002  พญ. วิภาดา รักษาดี
# 4        005  2026-08-29 10:50:10        P118    D003   นพ. ธนกฤต เก่งกาจ
# 5        006  2026-08-29 14:40:00        P155    D002  พญ. วิภาดา รักษาดี
# 6        007  2026-08-29 15:32:34        P195    D003   นพ. ธนกฤต เก่งกาจ
# 7        008  2026-08-29 08:03:07        P108    D002  พญ. วิภาดา รักษาดี
# 8        009  2026-08-29 13:46:43        P155    D002  พญ. วิภาดา รักษาดี
# 9        010  2026-08-29 16:27:43        P231    D003   นพ. ธนกฤต เก่งกาจ
# 10       011  2026-08-29 13:44:12        P047    D001      นพ. สมชาย ใจดี
# 11       012  2026-08-29 12:04:46        P067    D003   นพ. ธนกฤต เก่งกาจ
# 12       013  2026-08-29 12:20:13        P157    D002  พญ. วิภาดา รักษาดี
# 13       014  2026-08-29 11:03:20        P099    D001      นพ. สมชาย ใจดี
# 14       015  2026-08-29 14:54:14        P163    D003   นพ. ธนกฤต เก่งกาจ
# 15       016  2026-08-29 08:36:39        P245    D003   นพ. ธนกฤต เก่งกาจ
# 16       017  2026-08-29 09:06:51        P112    D003   นพ. ธนกฤต เก่งกาจ
# 17       018  2026-08-29 09:16:01        P121    D002  พญ. วิภาดา รักษาดี
# 18       019  2026-08-29 11:24:22        P166    D003   นพ. ธนกฤต เก่งกาจ
# 19       020  2026-08-29 08:33:17        P203    D002  พญ. วิภาดา รักษาดี
#
#                   อาการที่มา                                     ยาที่จะสั่ง  \
# 0           อาเจียนต่อเนื่อง              Domperidone 10mg, ORS, Paracetamol
# 1           อาเจียนต่อเนื่อง              Domperidone 10mg, ORS, Paracetamol
# 2           ช็อกจากเสียเลือด  ให้สารน้ำทางหลอดเลือดดำ (NSS/Ringer) เบื้องต้น
# 3              ผื่นคันตามตัว                Cetirizine 10mg, Calamine Lotion
# 4              ปวดกล้ามเนื้อ              Analgesic Cream, Paracetamol 500mg
# 5          อุบัติเหตุร้ายแรง              ปฐมพยาบาลเบื้องต้น ห้ามเลือด ดามคอ
# 6            เจ็บคอ ถ่ายเหลว             Amoxicillin 500mg, ORS, Paracetamol
# 7        กระดูกแขนผื่นผิดรูป                Splinting, Tramadol, Paracetamol
# 8          อุบัติเหตุร้ายแรง        C-spine Immobilization, Morphine IV, NSS
# 9          หมดสติ แน่นหน้าอก                   Aspirin 300mg, Oxygen Therapy
# 10             ปวดกล้ามเนื้อ              Analgesic Cream, Paracetamol 500mg
# 11           ขอใบรับรองแพทย์                                  ไม่มีการจ่ายยา
# 12           ฉีดวัคซีนตามนัด                             Hepatitis B Vaccine
# 13           ขอใบรับรองแพทย์                                  ไม่มีการจ่ายยา
# 14         ปวดศีรษะเฉียบพลัน                        Triptan, Ibuprofen 400mg
# 15         ปวดศีรษะเฉียบพลัน                        Triptan, Ibuprofen 400mg
# 16       กระดูกแขนผื่นผิดรูป                Splinting, Tramadol, Paracetamol
# 17           ฉีดวัคซีนตามนัด                             Hepatitis B Vaccine
# 18          ช็อกจากเสียเลือด  ให้สารน้ำทางหลอดเลือดดำ (NSS/Ringer) เบื้องต้น
# 19  ปรึกษาเรื่องสุขภาพทั่วไป                                 Vitamin C 500mg
#
#                                 สถานะรักษา
# 0                นัดติดตามอาการ / ออกใบนัด
# 1                              อาการดีขึ้น
# 2   ส่งตัวรักษาต่อโรงพยาบาล (ออกใบรีเฟอร์)
# 3                                   หายขาด
# 4                                   หายขาด
# 5   ส่งตัวรักษาต่อโรงพยาบาล (ออกใบรีเฟอร์)
# 6                              อาการดีขึ้น
# 7   ส่งตัวรักษาต่อโรงพยาบาล (ออกใบรีเฟอร์)
# 8   ส่งตัวรักษาต่อโรงพยาบาล (ออกใบรีเฟอร์)
# 9   ส่งตัวรักษาต่อโรงพยาบาล (ออกใบรีเฟอร์)
# 10                             อาการดีขึ้น
# 11                                  หายขาด
# 12                                  หายขาด
# 13                                  หายขาด
# 14                             อาการดีขึ้น
# 15               นัดติดตามอาการ / ออกใบนัด
# 16  ส่งตัวรักษาต่อโรงพยาบาล (ออกใบรีเฟอร์)
# 17                                  หายขาด
# 18  ส่งตัวรักษาต่อโรงพยาบาล (ออกใบรีเฟอร์)
# 19                             อาการดีขึ้น

# %% [markdown]
# **ชำระเงิน**

# %%
# รายการสถานะการชำระเงิน
payment_statuses = ["ชำระแล้ว", "ชำระแล้ว", "ชำระแล้ว", "รอชำระเงิน"]

# %%
records_list = df_medical_records.to_dict('records')
bills_list = []

# %%
# สุ่ม
for i, rec in enumerate(records_list, 1):
    # รหัสบิล
    bill_id = f"B{i:04d}"

    # ดึงรหัสรักษา ผู้ป่วย
    record_id = rec.get("รหัสรักษา")
    p_id = rec.get("รหัสผู้ป่วย")

    # สุ่มราคาชำระเงิน
    treatment_fee = float(random.choice([200, 300, 400, 500]))

    # กำหนดค่ายา
    meds = rec.get("ยาที่จะสั่ง", "")
    if "Paracetamol" in meds:
        medication_fee = float(random.randint(50, 150))
    elif "Aspirin" in meds or "Ventolin" in meds:
        medication_fee = float(random.randint(250, 600))
    else:
        medication_fee = float(random.randint(300, 1200))

    # คำนวณราคารวม
    total_payment = round(treatment_fee + medication_fee, 2)

    # สถานะการจ่ายเงิน
    status = random.choice(payment_statuses)

    bills_list.append({
        "รหัสใบแจ้งหนี้": bill_id,
        "รหัสการรักษา": record_id,
        "รหัสผู้ป่วย": p_id,
        "ค่าบริการ": treatment_fee,
        "ค่ายา": medication_fee,
        "ยอดชำระรวม": total_payment,
        "สถานะการชำระเงิน": status
    })

# %%
print(f"จำนวนบิลที่สร้าง: {len(df_bills)} แถว")
# Out:
# จำนวนบิลที่สร้าง: 1000 แถว

# %%
df_bills = pd.DataFrame(bills_list)
df_bills.to_csv("bills.csv", index=False, encoding="utf-8-sig")

print("สร้างข้อมูลคนเรียบร้อยแล้ว!")
files.download("bills.csv")
# Out:
# สร้างข้อมูลคนเรียบร้อยแล้ว!

# %%
df_bills.head(10)
# Out:
#   รหัสใบแจ้งหนี้ รหัสการรักษา รหัสผู้ป่วย  ค่าบริการ   ค่ายา  ยอดชำระรวม  \
# 0          B0001          001        P038      500.0    74.0       574.0
# 1          B0002          002        P148      300.0   123.0       423.0
# 2          B0003          003        P051      300.0  1032.0      1332.0
# 3          B0004          004        P253      300.0   750.0      1050.0
# 4          B0005          005        P118      500.0    71.0       571.0
# 5          B0006          006        P155      300.0  1043.0      1343.0
# 6          B0007          007        P195      400.0   143.0       543.0
# 7          B0008          008        P108      300.0    89.0       389.0
# 8          B0009          009        P155      500.0   494.0       994.0
# 9          B0010          010        P231      400.0   356.0       756.0
#
#   สถานะการชำระเงิน
# 0       รอชำระเงิน
# 1         ชำระแล้ว
# 2         ชำระแล้ว
# 3         ชำระแล้ว
# 4       รอชำระเงิน
# 5         ชำระแล้ว
# 6         ชำระแล้ว
# 7         ชำระแล้ว
# 8         ชำระแล้ว
# 9         ชำระแล้ว
